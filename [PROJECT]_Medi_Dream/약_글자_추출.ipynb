# %%
pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install pytesseract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 3.2 MB 4.5 MB/s
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ...

# %%
pip install tesseract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 45.6 MB 94 kB/s
# ...
#   Created wheel for tesseract: filename=tesseract-0.1.3-py3-none-any.whl size=45562571 sha256=f3f16b508c459e7ced8bbb174d9cef40330d15ed2c18f9f9c48d61644519f224
#   Stored in directory: /root/.cache/pip/wheels/7f/a1/69/fabe07004553a36d818e4657fed410daf525fe1ae161f469d3
# Successfully built tesseract
# ...

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:\Program Files\Tesseract-OCR'

# %%
# !sudo apt-get install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 5 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# ...

# %%
# !pip install pytesseract==0.3.9
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: pytesseract
#     Found existing installation: pytesseract 0.3.10
#     Uninstalling pytesseract-0.3.10:
#       Successfully uninstalled pytesseract-0.3.10
# ...

# %%
from PIL import Image
import pytesseract


filename = "/content/KakaoTalk_20221125_132120632.png"
image = Image.open(filename)
text = pytesseract.image_to_string(image, lang="eng")
print(text)
# Out:
# “Teave

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread('/content/1.jpg')

plt.imshow(image);plt.show()

# %%
# 커널 생성 (대상이 있는 픽셀을 강조)
kernel = np.array([[0,-1,0],
                   [-1,5,-1],
                   [0,-1,0]])

# 커널 적용
image_sharp = cv2.filter2D(image, -1, kernel)

plt.imshow(image_sharp)
plt.show()

# %%
# 이미지 IMREAD_GRAYSCALE로 출력해야 함
image = cv2.imread('/content/1.jpg', cv2.IMREAD_GRAYSCALE)

# 이미지 대비 향상
image_enhanced = cv2.equalizeHist(image)

plt.imshow(image_enhanced)
plt.show()

# %%
# adaptive thresholding 적용
max_output_value = 255
neighborhood_size = 99
subtract_from_mean = 10

image_binarized = cv2.adaptiveThreshold(img_gray,
                                        max_output_value,
                                        cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                        cv2.THRESH_BINARY,
                                        neighborhood_size,
                                        subtract_from_mean)

plt.imshow(image_binarized, cmap = 'gray')
plt.show()

# %%
cv2.imwrite('3.jpg', image_binarized)
# Out:
# True

# %%
img = cv2.imread("/content/1.jpg")
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray)

# %%
img_checker = cv2.adaptiveThreshold(image_binarized, 255, 
                                    cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                    cv2.THRESH_BINARY_INV, 191, 6)
plt.imshow(img_checker)
plt.show()

# %%
cv2.imwrite('4.jpg', img_checker)
# Out:
# True

# %%
image_grey = cv2.imread('/content/1.jpg', cv2.IMREAD_GRAYSCALE)


# Adaptive Thresholding 적용 
max_output_value = 255   # 출력 픽셀 강도의 최대값
neighborhood_size = 99
subtract_from_mean = 10
image_binarized = cv2.adaptiveThreshold(image_grey,
                                       max_output_value,
                                       cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                       cv2.THRESH_BINARY,
                                       neighborhood_size,
                                       subtract_from_mean)

plt.imshow(image_binarized, cmap='gray')

# %%
norm_img = np.zeros((img.shape[0], img.shape[1]))
img = cv2.normalize(img_checker, norm_img, 0, 255, cv2.NORM_MINMAX)
img = cv2.threshold(img, 100, 255, cv2.THRESH_BINARY)[1]
img = cv2.GaussianBlur(img, (1,1), 0)

plt.imshow(img)

# %%
img = cv2.imread("/content/1.jpg")
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray)

# %%
img_checker = cv2.adaptiveThreshold(img_gray, 255, 
                                    cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                    cv2.THRESH_BINARY_INV, 191, 6)
plt.imshow(img_checker, cmap = 'gray')
plt.show()

# %%
cv2.imwrite('2.jpg', img_checker)
# Out:
# True

# %%
img = cv2.imread("/content/2.jpg")
out = img.copy()
out = 255-out

plt.imshow(out)

# %%
cv2.imwrite('5.jpg', out)
# Out:
# True

# %%
norm_img = np.zeros((img_checker.shape[0], img_checker.shape[1]))
img = cv2.normalize(img_checker, norm_img, 0, 255, cv2.NORM_MINMAX)
img = cv2.threshold(img, 100, 255, cv2.THRESH_BINARY)[1]
img = cv2.GaussianBlur(img, (1,1), 0)

# %%
filename = '/content/1.jpg'
image = cv2.imread(filename)

# %%
from pytesseract import Output
results = pytesseract.image_to_data(image, output_type = Output.DICT)
results
# Out:
# {'level': [1, 2, 3, 4, 5],
#  'page_num': [1, 1, 1, 1, 1],
#  'block_num': [0, 1, 1, 1, 1],
#  'par_num': [0, 0, 1, 1, 1],
#  'line_num': [0, 0, 0, 1, 1],
#  'word_num': [0, 0, 0, 0, 1],
#  'left': [0, 0, 0, 0, 0],
#  'top': [0, 0, 0, 0, 0],
#  'width': [3024, 3024, 3024, 3024, 3024],
#  'height': [3024, 3024, 3024, 3024, 3024],
#  'conf': ['-1', '-1', '-1', '-1', 95],
#  'text': ['', '', '', '', '']}

# %%
for i in range(0, len(results['text'])):
  x = results['left'][i]
  y = results['top'][i]

  w = results['width'][i]
  h = results['height'][i]
  text = results['text'][i]
  conf = int(results['conf'][i])

  if conf > 70:
    text = "".join([c if ord(c) < 128 else "" for c in text]).strip()
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0),2)
    cv2.putText(image, text, (x,y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,200),2)

# %%
plt.imshow(image)

# %% [markdown]
# ### 글자 추출 - canny edge

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/1.jpg', cv2.IMREAD_GRAYSCALE)
edge1 = cv2.Canny(img, 0.0000000001,0.0000005)
plt.imshow(edge1, cmap = 'gray')

# %%
img = cv2.imread('/content/1.jpg', cv2.IMREAD_GRAYSCALE)
lap = cv2.Laplacian(img, cv2.CV_32F)
sobelx = cv2.Sobel(img, cv2.CV_32F, 1,0, ksize = 3)
sobely = cv2.Sobel(img, cv2.CV_32F, 0,1, ksize = 3)
plt.imshow(lap, cmap = 'gray')

# %%
img = cv2.imread('/content/1.jpg', cv2.IMREAD_GRAYSCALE)
tmp = cv2.Sobel(img, cv2.CV_64F, 1,0, ksize = -1)
sobel64f = np.absolute(tmp)
sobelx8u2 = np.uint8(sobel64f)

plt.imshow(sobelx8u2)
